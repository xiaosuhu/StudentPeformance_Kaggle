# %%
import pickle

with open('./Version46/importance_dict.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
print(data)
# Out:
# {'1': ['session_number_', 'event_name_unique_', 'name_unique_', 'fqid_unique_', 'room_fqid_unique_', 'text_fqid_unique_', 'page_mean_', 'room_coor_x_mean_', 'room_coor_y_mean_', 'screen_coor_x_mean_', 'screen_coor_y_mean_', 'hover_duration_mean_', 'elapsed_time_diff_mean_', 'page_median_', 'room_coor_x_median_', 'room_coor_y_median_', 'screen_coor_x_median_', 'screen_coor_y_median_', 'hover_duration_median_', 'elapsed_time_diff_median_', 'page_std_', 'room_coor_x_std_', 'room_coor_y_std_', 'screen_coor_x_std_', 'screen_coor_y_std_', 'hover_duration_std_', 'elapsed_time_diff_std_', 'page_q25_', 'room_coor_x_q25_', 'room_coor_y_q25_', 'screen_coor_x_q25_', 'screen_coor_y_q25_', 'hover_duration_q25_', 'elapsed_time_diff_q25_', 'page_q75_', 'room_coor_x_q75_', 'room_coor_y_q75_', 'screen_coor_x_q75_', 'screen_coor_y_q75_', 'hover_duration_q75_', 'elapsed_time_diff_q75_', 'word_that', 'word_this', 'word_it', 'word_you', 'word_find', 'word_Found', 'word_notebook', 'word_Wells', 'word_help'
# ...

# %%
data['18']
# Out:
# ['session_number_',
#  'event_name_unique_',
#  'name_unique_',
#  'fqid_unique_',
#  'room_fqid_unique_',
#  'text_fqid_unique_',
#  'page_mean_',
#  'room_coor_x_mean_',
#  'room_coor_y_mean_',
#  'screen_coor_x_mean_',
#  'screen_coor_y_mean_',
#  'hover_duration_mean_',
#  'elapsed_time_diff_mean_',
#  'page_median_',
#  'room_coor_x_median_',
#  'room_coor_y_median_',
#  'screen_coor_x_median_',
#  'screen_coor_y_median_',
#  'hover_duration_median_',
#  'elapsed_time_diff_median_',
#  'page_std_',
#  'room_coor_x_std_',
#  'room_coor_y_std_',
#  'screen_coor_x_std_',
#  'screen_coor_y_std_',
#  'hover_duration_std_',
#  'elapsed_time_diff_std_',
#  'page_q25_',
#  'room_coor_x_q25_',
#  'room_coor_y_q25_',
#  'screen_coor_x_q25_',
#  'screen_coor_y_q25_',
#  'hover_duration_q25_',
#  'elapsed_time_diff_q25_',
#  'page_q75_',
#  'room_coor_x_q75_',
#  'room_coor_y_q75_',
#  'screen_coor_x_q75_',
#  'screen_coor_y_q75_',
#  'hover_duration_q75_',
#  'elapsed_time_diff_q75_',
# ...
